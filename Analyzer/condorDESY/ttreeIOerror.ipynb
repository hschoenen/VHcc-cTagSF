# %%
import uproot4

# %%
rootfile = uproot4.open('/pnfs/desy.de/cms/tier2/store/user/spmondal/VHccPostV11_Nanov5_Jul19/2017/DYJetsToLL_M-50_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIFall17NanoAODv5-PU2017REC16/190726_135011/0000/tree_29.root')

# %%
rootfile
# Out:
# <ReadOnlyDirectory '/' at 0x7fe70c6b03d0>

# %%
rootfile.keys()
# Out:
# ['autoPU;1',
#  'Events;1',
#  'Runs;1',
#  'ParameterSets;1',
#  'LuminosityBlocks;1',
#  'MetaData;1',
#  'untagged;1']

# %%
rootfile['Events'].keys()
# Out:
# ['run',
#  'luminosityBlock',
#  'event',
#  'HTXS_Higgs_pt',
#  'HTXS_Higgs_y',
#  'HTXS_stage1_1_cat_pTjet25GeV',
#  'HTXS_stage1_1_cat_pTjet30GeV',
#  'HTXS_stage1_1_fine_cat_pTjet25GeV',
#  'HTXS_stage1_1_fine_cat_pTjet30GeV',
#  'HTXS_stage_0',
#  'HTXS_stage_1_pTjet25',
#  'HTXS_stage_1_pTjet30',
#  'HTXS_njets25',
#  'HTXS_njets30',
#  'btagWeight_CSVV2',
#  'btagWeight_DeepCSVB',
#  'CaloMET_phi',
#  'CaloMET_pt',
#  'CaloMET_sumEt',
#  'ChsMET_phi',
#  'ChsMET_pt',
#  'ChsMET_sumEt',
#  'nCorrT1METJet',
#  'CorrT1METJet_area',
#  'CorrT1METJet_eta',
#  'CorrT1METJet_muonSubtrFactor',
#  'CorrT1METJet_phi',
#  'CorrT1METJet_rawPt',
#  'nElectron',
#  'Electron_deltaEtaSC',
#  'Electron_dr03EcalRecHitSumEt',
#  'Electron_dr03HcalDepth1TowerSumEt',
#  'Electron_dr03TkSumPt',
#  'Electron_dr03TkSumPtHEEP',
#  'Electron_dxy',
#  'Electron_dxyErr',
#  'Electron_dz',
#  'Electron_dzErr',
#  'Electron_eCorr',
#  'Electron_eInvMinusPInv',
#  'Electron_energyErr',
#  'Electron_eta',
# ...

# %%
rootfile['Events']['Electron_cleanmask']
# Out:
# <TBranch 'Electron_cleanmask' at 0x7fe5e47f56d0>

# %%
rootfile['Events']['Jet_hadronFlavour'].arrays()
# Out:
# <Array [{Jet_hadronFlavour: [0, 0, ... 0, 0]}] type='405474 * {"Jet_hadronFlavou...'>

# %%
rootfile['Events']['Electron_cleanmask'].arrays()
# Out:
# ---------------------------------------------------------------------------
# LZMAError                                 Traceback (most recent call last)
# <ipython-input-13-75a41526a38b> in <module>
# ----> 1 rootfile['Events']['Electron_cleanmask'].arrays()
#
# ~/miniconda3/envs/my-env/lib/python3.8/site-packages/uproot4/behaviors/TBranch.py in arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, how)
#    1056         if isinstance(self, TBranch) and expressions is None and len(keys) == 0:
#    1057             filter_branch = uproot4._util.regularize_filter(filter_branch)
# -> 1058             return self.parent.arrays(
#    1059                 expressions=expressions,
#    1060                 cut=cut,
#
# ...
